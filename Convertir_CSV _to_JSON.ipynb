# %%
FileName = 'Fichier_des_personnes.csv'
file = open(FileName, 'r').read().split('\n')
dico= {}
for i in file[0].split(';'):
    dico[i]=''
file_key = file[0].split(';')
del file[0]
del file_key[0:3]
liste_dico = []
for element in file:
    element = element.split(';')
    dico = {}
    del element[0:3]
    for key, value in zip(file_key, element):
        dico[key] = value
    liste_dico.append(dico)

# %%
def renommer_valeurs(dico):
    if 'PENQ' in dico:
        if dico['PENQ'] == '1':
            dico['PENQ'] = 'Oui'
        else:
            dico['PENQ'] = 'NON'

    if 'JOUR' in dico:
        if dico['JOUR'] == '1':
            dico['JOUR'] = 'Lundi'
        elif dico['JOUR'] == '2':
            dico['JOUR'] = 'mardi'
        elif dico['JOUR'] == '3':
            dico['JOUR'] = 'mercredi'
        elif dico['JOUR'] == '4':
            dico['JOUR'] = 'jeudi'
        elif dico['JOUR'] == '5':
            dico['JOUR'] = 'vendredi'

    if 'P2' in dico:
        if dico['P2'] == '1':
            dico['P2'] = 'Masculin'
        elif dico['P2'] == '2':
            dico['P2'] = 'Féminin'

    if 'P3' in dico:
        if dico['P3'] == '1':
            dico['P3'] = 'Personne de référence'
        elif dico['P3'] == '2':
            dico['P3'] = 'Conjoint'
        elif dico['P3'] == '3':
            dico['P3'] = 'Enfant'
        elif dico['P3'] == '4':
            dico['P3'] = 'Colocataire, locataire ou sous-locataire'
        elif dico['P3'] == '5':
            dico['P3'] = 'Autre (avec lien de parenté)'
        elif dico['P3'] == '6':
            dico['P3'] = 'Autre (sans lien de parenté)'
        elif dico['P3'] == '7':
            dico['P3'] = 'Autre Non précisé'

    if 'P5' in dico:
        if dico['P5'] == '1':
            dico['P5'] = 'Oui'
        elif dico['P5'] == '2':
            dico['P5'] = 'Non'

    if 'P6' in dico:
        if dico['P6'] == '1':
            dico['P6'] = 'Oui'
        elif dico['P6'] == '2':
            dico['P6'] = 'Non'

    if 'P7' in dico:
        if dico['P7'] == '1':
            dico['P7'] = 'OUI'
        elif dico['P7'] == '2':
            dico['P7'] = 'NON'
        elif dico['P7'] == '3':
            dico['P7'] = 'Conduite accompagnée et leçons de conduite'


    P8_dict = {
        '00': 'En cours de scolarité',
        '01': 'Primaire',
        '02': 'Secondaire (de la 6e à la 3e, CAP)',
        '03': 'Secondaire (de la seconde à la terminale, BEP), non titulaire du bac',
        '04': 'Secondaire, titulaire du bac',
        '05': 'Supérieur jusqu’à bac + 2',
        '06': 'Supérieur, bac + 3 et plus',
        '07': 'Apprentissage (école primaire ou secondaire uniquement)',
        '08': 'Apprentissage (études supérieures)',
        '09': 'Pas d’études',
        '93': 'Secondaire (sans distinction des titulaires du bac ou non)',
        '97': 'Apprentissage (sans distinction)',
        '90': 'autre (egt)',
    }

    P9_dict = {
        '1': 'Travail à plein temps',
        '2': 'Travail à temps partiel',
        '3': 'Formation en alternance (apprentissage, professionnalisation), stage',
        '4': 'Étudiant',
        '5': 'Scolaire jusqu\'au bac',
        '6': 'Chômeur, recherche un emploi',
        '7': 'Retraité',
        '8': 'Reste au foyer',
        '9': 'Autre',
    }

    PCSC_dict = {
        '00': 'Non réponse',
        '01': 'Agriculteurs exploitants',
        '02': 'Artisans, commerçants et chefs d\'entreprise',
        '03': 'Cadres et professions intellectuelles supérieures',
        '04': 'Professions Intermédiaires',
        '05': 'Employés',
        '06': 'Ouvriers',
        '07': 'Élèves, étudiants',
        '08': 'Chômeurs n\'ayant jamais travaillé',
        '09': 'Autres inactifs n\'ayant jamais travaillé',
    }

    if 'P8' in dico:
        dico['P8'] = P8_dict.get(dico['P8'], '')

    if 'P9' in dico:
        dico['P9'] = P9_dict.get(dico['P9'], '')

    if 'PCSC' in dico:
        dico['PCSC'] = PCSC_dict.get(dico['PCSC'], '')


    if 'P10' in dico:
        if dico['P10'] == '0':
            dico['P10'] = 'Non concerné'
        elif dico['P10'] == '1':
            dico['P10'] = 'Travail'
        elif dico['P10'] == '2':
            dico['P10'] = 'Etude'

    PCSD_dict = {
        '00': 'Non réponse',
        '10': 'Agriculteurs exploitants',
        '21': 'Artisans',
        '22': 'Commerçants et assimilés',
        '23': 'Chefs d\'entreprise de 10 salariés ou plus',
        '31': 'Professions libérales',
        '32': 'Cadres de la fonction publique, professions intellectuelles et artistiques, professeurs de lycée, professions scientifiques, professions de l\'information, des arts et des spectacles',
        '36': 'Cadres d\'entreprise, cadres administratifs, commerciaux et techniques d\'entreprise, ingénieurs',
        '41': 'Professions intermédiaires de l\'enseignement, de la santé, de la fonction publique et assimilés, instituteurs, professeurs d\'enseignement général des collèges, services médicaux et sociaux, clergé',
        '46': 'Professions intermédiaires administratives et commerciales des entreprises',
        '47': 'Techniciens',
        '48': 'Contremaîtres, agents de maîtrise',
        '51': 'Employés de la fonction publique, agents de service, aides soignants, policiers, militaires, agents de surveillance',
        '54': 'Employés administratifs d\'entreprise, secrétaires, employés de bureau',
        '55': 'Employés de commerce',
        '56': 'Personnels des services directs aux particuliers, nourrices, gens de maison, femmes de ménage',
        '61': 'Ouvriers qualifiés, ouvriers spécialisés, chauffeurs',
        '66': 'Ouvriers non qualifiés',
        '69': 'Ouvriers agricoles',
        '81': 'Chômeurs n\'ayant jamais travaillé',
        '82': 'Inactifs divers (autres que retraités), femmes au foyer, militaires du contingent',
        '83': 'Écoliers (primaire)',
        '84': 'Secondaires jusqu\'en 3ème',
        '85': 'Secondaires, de la seconde à la terminale',
        '86': 'Secondaires, titulaires du Bac',
        '90': 'Secondaires, de la seconde à la terminale (Sans précision des titulaires du Bac ou non) egt',
        '87': 'Supérieurs (Bac+2)',
        '80': 'Sans précision secondaires titulaires du Bac + supérieurs (Bac+2)',
        '88': 'Supérieurs (Bac+3 et plus)',
        '89': 'Apprentis',
    }

    if 'PCSD' in dico:
        dico['PCSD'] = PCSD_dict.get(dico['PCSD'], '')

    P12_dict = {
        '1': 'Oui, gratuit',
        '2': 'Oui, payant avec prise en charge partielle par l\'employeur',
        '3': 'Oui, payant sans prise en charge partielle par l\'employeur',
        '4': 'Non',
        '5': 'Oui, payant (sans information sur la prise en charge)',
        '6': 'Oui, mais sans précision'
    }

    P14_dict = {
        '1': 'Oui',
        '2': 'Non'
    }

    P16_dict = {
        '1': 'Oui et je l’utilise jusqu\'à mon lieu de travail ou d\'études',
        '2': 'Oui mais je ne l’utilise que sur une partie du déplacement',
        '3': 'Oui, mais je ne l’utilise pas',
        '4': 'Non',
        '5': 'Oui, mais je ne l\'utilise qu\'en partie ou pas du tout (2+3 sans distinction)',
        '6': 'Oui et je l’utilise pour tout ou partie du déplacement (1+2 sans distinction)'
    }

    P17_dict = {
        '1': 'Oui',
        '2': 'Non, j\'ai une place réservée',
        '3': 'Non, il y a une offre de stationnement importante à proximité',
        '4': 'Non, compte tenu de mes horaires'
    }

    P18_dict = {
        '1': 'Oui',
        '2': 'Non, je pourrais avoir une place réservée',
        '3': 'Non, il y a une offre de stationnement importante à proximité'
    }

    P18A_dict = {
        '1': 'OUI, DANS L\'ENCEINTE DU LIEU ET ABRITÉ',
        '2': 'OUI, DANS L\'ENCEINTE DU LIEU MAIS NON ABRITÉ',
        '3': 'OUI, À PROXIMITÉ DU LIEU ET ABRITÉ',
        '4': 'OUI, À PROXIMITÉ DU LIEU MAIS NON ABRITÉ',
        '5': 'NON',
        '6': 'OUI , DANS L’ENCEINTE DU LIEU SANS PRECISION (ex : Amiens)',
        '7': 'OUI , DANS A PROXIMITE DU LIEU SANS PRECISION (ex : Amiens)'
    }

    if 'P12' in dico:
        dico['P12'] = P12_dict.get(dico['P12'], '')

    if 'P14' in dico:
        dico['P14'] = P14_dict.get(dico['P14'], '')

    if 'P16' in dico:
        dico['P16'] = P16_dict.get(dico['P16'], '')

    if 'P17' in dico:
        dico['P17'] = P17_dict.get(dico['P17'], '')

    if 'P18' in dico:
        dico['P18'] = P18_dict.get(dico['P18'], '')

    if 'P18A' in dico:
        dico['P18A'] = P18A_dict.get(dico['P18A'], '')

    P19_P24_dict = {
        '1':'Tous les jours ou presque',
        '2':'Au moins 2 déplacements par semaine',
        '3':'Au moins 2 déplacements par mois',
        '4':'Exceptionnellement',
        '5':'Jamais'
    }

    for key in ['P19', 'P20', 'P21', 'P22', 'P23', 'P24']:
        if key in dico:
            dico[key] = P19_P24_dict.get(dico[key], '')


    P25_dict = {        
        '1':'Oui, déplacement dans la zone d\'enquête',
        '2':'Non, pas de déplacement dans la zone d\'enquête',
        '3':'Absent (vieille enquête – avant 2009)',
        '4':'déplacements non relevés',
        '5':'absent - longue durée-'
    }

    if 'P25' in dico:
        dico['P25'] = P25_dict.get(dico['P25'], '')


    P26_dict = {
        '1':'Oui, hors du domicile',
        '2':'Oui mais à domicile (travail toujours au domicile)',
        '3':'Oui mais à domicile – télétravail',
        '4':'Oui mais à domicile - autre',
        '5':'Non, ne travaille jamais ce jour-là',
        '6':'Non en raison de congés, grève ou maladie',
        '7':'oui (sans précision)',
        '8':'non (sans précision)'
    }
    if 'P26' in dico:
        dico['P26'] = P25_dict.get(dico['P26'], '')
    
    return dico

# %%
liste2 = []
for dico in liste_dico:
    liste2.append(renommer_valeurs(dico))

# %%
NewKey = ['Zone fine',
         'Num Echantillon',
         'Num Personne',
         'Insee Zone Fine',
         'STP',
         'ANNEE',
         'MOIS',
         'DATE',
         'JOUR',
         'Personne Enquêtée',
         'Sexe',
         'Lien avec la personne de référence',
         'Âge',
         'Tél Portable',
         'Mail',
         'Permis de conduire',
         "Niveau d'études",
         'Occupation principale de la personne',
         'Occupation Secondaire',
         'Professions et Catégories Socioprofessionnelles Courte',
         'Professions et Catégories Socioprofessionnelles Détaillé',
         'Abonnement TC Valide',
         'Travail, étude à domicile',
         "Zone de travail ou d'études",
         "Distance domicile-travail/étude à vol d'oiseau",
         'Insee Zone fine',
         'STW',
         "VP conducteur pour se rendre sur le lieu de travail ou d'études",
         "Problèmes de stationnement sur le lieu de travail ou d'études",
         "Difficultés de stationnement sur le lieu de travail ou d'études",
         'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES',
         'Fréquence marche',
         "Fréquence d’utilisation d'un vélo",
         "Fréquence d’utilisation d'un deux-roues motorisé",
         'Fréquence d’utilisation de la VP conducteur',
         'Fréquence d’utilisation de la VP passager',
         'Fréquence d’utilisation du réseau urbain',
         'Situation la veille du jour d’enquête',
         'Travail la veille',
         'Coefficient de redressement toutes personnes',
         'Coefficient de redressement personnes enquêtées']

# %%
liste3 = []
for dico in liste2:
    liste4 = []
    for key, value in dico.items():
        liste4.append(value)
    liste3.append(liste4)
Final_Dict = {}
count = 1
for element in liste3:
    FinalDico = {}
    for key, value in zip(NewKey ,element):
        FinalDico[key] = value
    Final_Dict[count] = FinalDico
    count += 1

# %%
liste3
# Out:
# [['00001005',
#   '1',
#   '1',
#   '31555',
#   '0001',
#   '2012',
#   '12',
#   '08',
#   'vendredi',
#   'Oui',
#   'Féminin',
#   'Personne de référence',
#   '32',
#   'Oui',
#   'Oui',
#   'OUI',
#   'Supérieur, bac + 3 et plus',
#   'Travail à plein temps',
#   'Non concerné',
#   'Cadres et professions intellectuelles supérieures',
#   "Cadres d'entreprise, cadres administratifs, commerciaux et techniques d'entreprise, ingénieurs",
#   "Oui, payant avec prise en charge partielle par l'employeur",
#   'Non',
#   '00030034',
#   '5560',
#   '31069',
#   '0030',
#   'Non',
#   '',
#   'Oui',
#   "OUI, DANS L'ENCEINTE DU LIEU ET ABRITÉ",
#   '',
#   'Au moins 2 déplacements par semaine',
#   'Exceptionnellement',
#   'Exceptionnellement',
#   'Au moins 2 déplacements par semaine',
#   'Tous les jours ou presque',
#   "Oui, déplacement dans la zone d'enquête",
#   "Oui, déplacement dans la zone d'enquête",
#   '69.4492',
#   '69.4492'],
#  ['00001003',
#   '2',
#   '1',
# ...

# %%
Final_Dict = {}
count = 1
for element in liste3:
    FinalDico = {}
    for key, value in zip(NewKey ,element):
        FinalDico[key] = value
    Final_Dict[count] = FinalDico
    count += 1

# %%
Final_Dict
# Out:
# {1: {'Zone fine': '00001005',
#   'Num Echantillon': '1',
#   'Num Personne': '1',
#   'Insee Zone Fine': '31555',
#   'STP': '0001',
#   'ANNEE': '2012',
#   'MOIS': '12',
#   'DATE': '08',
#   'JOUR': 'vendredi',
#   'Personne Enquêtée': 'Oui',
#   'Sexe': 'Féminin',
#   'Lien avec la personne de référence': 'Personne de référence',
#   'Âge': '32',
#   'Tél Portable': 'Oui',
#   'Mail': 'Oui',
#   'Permis de conduire': 'OUI',
#   "Niveau d'études": 'Supérieur, bac + 3 et plus',
#   'Occupation principale de la personne': 'Travail à plein temps',
#   'Occupation Secondaire': 'Non concerné',
#   'Professions et Catégories Socioprofessionnelles Courte': 'Cadres et professions intellectuelles supérieures',
#   'Professions et Catégories Socioprofessionnelles Détaillé': "Cadres d'entreprise, cadres administratifs, commerciaux et techniques d'entreprise, ingénieurs",
#   'Abonnement TC Valide': "Oui, payant avec prise en charge partielle par l'employeur",
# ...

# %%
import json

NewFileName = 'Dictionnaire_Personnes.json'
NewFile = open(NewFileName, 'w')
json.dump(Final_Dict,NewFile)

# %%
    #Extrait
    P8_dict = {
        '00': 'En cours de scolarité',
        '01': 'Primaire',
        '02': 'Secondaire (de la 6e à la 3e, CAP)',
        '03': 'Secondaire (de la seconde à la terminale, BEP), non titulaire du bac',
        '04': 'Secondaire, titulaire du bac',
        '05': 'Supérieur jusqu’à bac + 2',
        '06': 'Supérieur, bac + 3 et plus',
        '07': 'Apprentissage (école primaire ou secondaire uniquement)',
        '08': 'Apprentissage (études supérieures)',
        '09': 'Pas d’études',
        '93': 'Secondaire (sans distinction des titulaires du bac ou non)',
        '97': 'Apprentissage (sans distinction)',
        '90': 'autre (egt)',
    }
    if 'P8' in dico:
        dico['P8'] = P8_dict.get(dico['P8'], '')

# %% [markdown]
# 3: {'Zone fine': '00001006',
#   'Num Echantillon': '5',
#   'Num Personne': '1',
#   'Insee Zone Fine': '31555',
#   'STP': '0001',
#   'ANNEE': '2012',
#   'MOIS': '11',
#   'DATE': '28',
#   'JOUR': 'mardi',
#   'Personne Enquêtée': 'Oui',
#   'Sexe': 'Masculin',
#   'Lien avec la personne de référence': 'Personne de référence',
#   'Âge': '76',
#   'Tél Portable': 'Oui',
#   'Mail': 'Non',
#   'Permis de conduire': 'OUI',
#   "Niveau d'études": 'Supérieur, bac + 3 et plus',
#   'Occupation principale de la personne': 'Retraité',
#   'Occupation Secondaire': 'Non concerné',
#   'Professions et Catégories Socioprofessionnelles Courte': "Artisans, commerçants et chefs d'entreprise",
#   'Professions et Catégories Socioprofessionnelles Détaillé': "Chefs d'entreprise de 10 salariés ou plus",
#   'Abonnement TC Valide': "Oui, payant sans prise en charge partielle par l'employeur",
#   'Travail, étude à domicile': '',
#   "Zone de travail ou d'études": '',
#   "Distance domicile-travail/étude à vol d'oiseau": '',
#   'Insee Zone fine': '',
#   'STW': '',
#   "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
#   "Problèmes de stationnement sur le lieu de travail ou d'études": '',
#   "Difficultés de stationnement sur le lieu de travail ou d'études": '',
#   'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
#   'Fréquence marche': '',
#   "Fréquence d’utilisation d'un vélo": 'Jamais',
#   "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
#   'Fréquence d’utilisation de la VP conducteur': 'Au moins 2 déplacements par semaine',
#   'Fréquence d’utilisation de la VP passager': 'Exceptionnellement',
#   'Fréquence d’utilisation du réseau urbain': 'Au moins 2 déplacements par mois',
#   'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
#   'Travail la veille': '',
#   'Coefficient de redressement toutes personnes': '44.0683',
#   'Coefficient de redressement personnes enquêtées': '44.0683'},
#
#
#
#  4: {'Zone fine': '00001006',
#   'Num Echantillon': '5',
#   'Num Personne': '2',
#   'Insee Zone Fine': '31555',
#   'STP': '0001',
#   'ANNEE': '2012',
#   'MOIS': '11',
#   'DATE': '28',
#   'JOUR': 'mardi',
#   'Personne Enquêtée': 'Oui',
#   'Sexe': 'Féminin',
#   'Lien avec la personne de référence': 'Conjoint',
#   'Âge': '68',
#   'Tél Portable': 'Oui',
#   'Mail': 'Oui',
#   'Permis de conduire': 'OUI',
#   "Niveau d'études": 'Supérieur, bac + 3 et plus',
#   'Occupation principale de la personne': 'Retraité',
#   'Occupation Secondaire': 'Non concerné',
#   'Professions et Catégories Socioprofessionnelles Courte': 'Cadres et professions intellectuelles supérieures',
#   'Professions et Catégories Socioprofessionnelles Détaillé': "Cadres de la fonction publique, professions intellectuelles et artistiques, professeurs de lycée, professions scientifiques, professions de l'information, des arts et des spectacles",
#   'Abonnement TC Valide': "Oui, payant sans prise en charge partielle par l'employeur",
#   'Travail, étude à domicile': '',
#   "Zone de travail ou d'études": '',
#   "Distance domicile-travail/étude à vol d'oiseau": '',
#   'Insee Zone fine': '',
#   'STW': '',
#   "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
#   "Problèmes de stationnement sur le lieu de travail ou d'études": '',
#   "Difficultés de stationnement sur le lieu de travail ou d'études": '',
#   'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
#   'Fréquence marche': '',
#   "Fréquence d’utilisation d'un vélo": 'Jamais',
#   "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
#   'Fréquence d’utilisation de la VP conducteur': 'Au moins 2 déplacements par semaine',
#   'Fréquence d’utilisation de la VP passager': 'Au moins 2 déplacements par semaine',
#   'Fréquence d’utilisation du réseau urbain': 'Au moins 2 déplacements par semaine',
#   'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
#   'Travail la veille': '',
#   'Coefficient de redressement toutes personnes': '44.0683',
#   'Coefficient de redressement personnes enquêtées': '44.0683'}

# %%
10: {'Zone fine': '00001005',
  'Num Echantillon': '17',
  'Num Personne': '1',
  'Insee Zone Fine': '31555',
  'STP': '0001',
  'ANNEE': '2012',
  'MOIS': '11',
  'DATE': '24',
  'JOUR': 'vendredi',
  'Personne Enquêtée': 'Oui',
  'Sexe': 'Masculin',
  'Lien avec la personne de référence': 'Personne de référence',
  'Âge': '49',
  'Tél Portable': 'Oui',
  'Mail': 'Oui',
  'Permis de conduire': 'OUI',
  "Niveau d'études": 'Supérieur, bac + 3 et plus',
  'Occupation principale de la personne': 'Travail à plein temps',
  'Occupation Secondaire': 'Non concerné',
  'Professions et Catégories Socioprofessionnelles Courte': 'Cadres et professions intellectuelles supérieures',
  'Professions et Catégories Socioprofessionnelles Détaillé': 'Professions libérales',
  'Abonnement TC Valide': 'Non',
  'Travail, étude à domicile': 'Non',
  "Zone de travail ou d'études": '00002017',
  "Distance domicile-travail/étude à vol d'oiseau": '542',
  'Insee Zone fine': '31555',
  'STW': '0002',
  "VP conducteur pour se rendre sur le lieu de travail ou d'études": 'Oui, mais je ne l’utilise pas',
  "Problèmes de stationnement sur le lieu de travail ou d'études": '',
  "Difficultés de stationnement sur le lieu de travail ou d'études": 'Oui',
  'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': "OUI, DANS L'ENCEINTE DU LIEU ET ABRITÉ",
  'Fréquence marche': '',
  "Fréquence d’utilisation d'un vélo": 'Tous les jours ou presque',
  "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
  'Fréquence d’utilisation de la VP conducteur': 'Au moins 2 déplacements par semaine',
  'Fréquence d’utilisation de la VP passager': 'Au moins 2 déplacements par semaine',
  'Fréquence d’utilisation du réseau urbain': 'Au moins 2 déplacements par mois',
  'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
  'Travail la veille': "Oui, déplacement dans la zone d'enquête",
  'Coefficient de redressement toutes personnes': '19.2385',
  'Coefficient de redressement personnes enquêtées': '19.2385'},
    
    
11: {'Zone fine': '00001005',
  'Num Echantillon': '17',
  'Num Personne': '2',
  'Insee Zone Fine': '31555',
  'STP': '0001',
  'ANNEE': '2012',
  'MOIS': '11',
  'DATE': '24',
  'JOUR': 'vendredi',
  'Personne Enquêtée': 'Oui',
  'Sexe': 'Féminin',
  'Lien avec la personne de référence': 'Conjoint',
  'Âge': '44',
  'Tél Portable': 'Oui',
  'Mail': 'Oui',
  'Permis de conduire': 'OUI',
  "Niveau d'études": 'Supérieur, bac + 3 et plus',
  'Occupation principale de la personne': 'Travail à temps partiel',
  'Occupation Secondaire': 'Non concerné',
  'Professions et Catégories Socioprofessionnelles Courte': 'Cadres et professions intellectuelles supérieures',
  'Professions et Catégories Socioprofessionnelles Détaillé': 'Professions libérales',
  'Abonnement TC Valide': "Oui, payant sans prise en charge partielle par l'employeur",
  'Travail, étude à domicile': 'Oui',
  "Zone de travail ou d'études": '',
  "Distance domicile-travail/étude à vol d'oiseau": '',
  'Insee Zone fine': '',
  'STW': '',
  "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
  "Problèmes de stationnement sur le lieu de travail ou d'études": '',
  "Difficultés de stationnement sur le lieu de travail ou d'études": '',
  'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
  'Fréquence marche': '',
  "Fréquence d’utilisation d'un vélo": 'Au moins 2 déplacements par semaine',
  "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
  'Fréquence d’utilisation de la VP conducteur': 'Au moins 2 déplacements par semaine',
  'Fréquence d’utilisation de la VP passager': 'Exceptionnellement',
  'Fréquence d’utilisation du réseau urbain': 'Au moins 2 déplacements par mois',
  'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
  'Travail la veille': "Oui, déplacement dans la zone d'enquête",
  'Coefficient de redressement toutes personnes': '19.2385',
  'Coefficient de redressement personnes enquêtées': '19.2385'},

12 : {'Zone fine': '00001005',
  'Num Echantillon': '17',
  'Num Personne': '3',
  'Insee Zone Fine': '31555',
  'STP': '0001',
  'ANNEE': '2012',
  'MOIS': '11',
  'DATE': '24',
  'JOUR': 'vendredi',
  'Personne Enquêtée': 'Oui',
  'Sexe': 'Masculin',
  'Lien avec la personne de référence': 'Enfant',
  'Âge': '17',
  'Tél Portable': 'Oui',
  'Mail': 'Oui',
  'Permis de conduire': 'NON',
  "Niveau d'études": 'En cours de scolarité',
  'Occupation principale de la personne': 'Étudiant',
  'Occupation Secondaire': 'Non concerné',
  'Professions et Catégories Socioprofessionnelles Courte': 'Élèves, étudiants',
  'Professions et Catégories Socioprofessionnelles Détaillé': 'Secondaires, titulaires du Bac',
  'Abonnement TC Valide': 'Non',
  'Travail, étude à domicile': 'Non',
  "Zone de travail ou d'études": '00888888',
  "Distance domicile-travail/étude à vol d'oiseau": '',
  'Insee Zone fine': 'aaaaa',
  'STW': '9999',
  "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
  "Problèmes de stationnement sur le lieu de travail ou d'études": '',
  "Difficultés de stationnement sur le lieu de travail ou d'études": '',
  'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
  'Fréquence marche': '',
  "Fréquence d’utilisation d'un vélo": '',
  "Fréquence d’utilisation d'un deux-roues motorisé": '',
  'Fréquence d’utilisation de la VP conducteur': '',
  'Fréquence d’utilisation de la VP passager': '',
  'Fréquence d’utilisation du réseau urbain': '',
  'Situation la veille du jour d’enquête': "Non, pas de déplacement dans la zone d'enquête",
  'Travail la veille': '',
  'Coefficient de redressement toutes personnes': '19.2385',
 
 
  'Coefficient de redressement personnes enquêtées': '19.2385'},
 13: {'Zone fine': '00001005',
  'Num Echantillon': '17',
  'Num Personne': '4',
  'Insee Zone Fine': '31555',
  'STP': '0001',
  'ANNEE': '2012',
  'MOIS': '11',
  'DATE': '24',
  'JOUR': 'vendredi',
  'Personne Enquêtée': 'Oui',
  'Sexe': 'Féminin',
  'Lien avec la personne de référence': 'Enfant',
  'Âge': '14',
  'Tél Portable': 'Oui',
  'Mail': 'Oui',
  'Permis de conduire': 'NON',
  "Niveau d'études": 'En cours de scolarité',
  'Occupation principale de la personne': "Scolaire jusqu'au bac",
  'Occupation Secondaire': 'Non concerné',
  'Professions et Catégories Socioprofessionnelles Courte': 'Élèves, étudiants',
  'Professions et Catégories Socioprofessionnelles Détaillé': "Secondaires jusqu'en 3ème",
  'Abonnement TC Valide': "Oui, payant sans prise en charge partielle par l'employeur",
  'Travail, étude à domicile': 'Non',
  "Zone de travail ou d'études": '00009006',
  "Distance domicile-travail/étude à vol d'oiseau": '1140',
  'Insee Zone fine': '31555',
  'STW': '0009',
  "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
  "Problèmes de stationnement sur le lieu de travail ou d'études": '',
  "Difficultés de stationnement sur le lieu de travail ou d'études": '',
  'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
  'Fréquence marche': '',
  "Fréquence d’utilisation d'un vélo": 'Jamais',
  "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
  'Fréquence d’utilisation de la VP conducteur': 'Jamais',
  'Fréquence d’utilisation de la VP passager': 'Au moins 2 déplacements par semaine',
  'Fréquence d’utilisation du réseau urbain': 'Exceptionnellement',
  'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
  'Travail la veille': '',
  'Coefficient de redressement toutes personnes': '19.2385',
  'Coefficient de redressement personnes enquêtées': '19.2385
      
      
 14: {'Zone fine': '00001005',
  'Num Echantillon': '17',
  'Num Personne': '5',
  'Insee Zone Fine': '31555',
  'STP': '0001',
  'ANNEE': '2012',
  'MOIS': '11',
  'DATE': '24',
  'JOUR': 'vendredi',
  'Personne Enquêtée': 'Oui',
  'Sexe': 'Féminin',
  'Lien avec la personne de référence': 'Enfant',
  'Âge': '12',
  'Tél Portable': 'Oui',
  'Mail': 'Oui',
  'Permis de conduire': 'NON',
  "Niveau d'études": 'En cours de scolarité',
  'Occupation principale de la personne': "Scolaire jusqu'au bac",
  'Occupation Secondaire': 'Non concerné',
  'Professions et Catégories Socioprofessionnelles Courte': 'Élèves, étudiants',
  'Professions et Catégories Socioprofessionnelles Détaillé': "Secondaires jusqu'en 3ème",
  'Abonnement TC Valide': "Oui, payant sans prise en charge partielle par l'employeur",
  'Travail, étude à domicile': 'Non',
  "Zone de travail ou d'études": '00009006',
  "Distance domicile-travail/étude à vol d'oiseau": '1140',
  'Insee Zone fine': '31555',
  'STW': '0009',
  "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
  "Problèmes de stationnement sur le lieu de travail ou d'études": '',
  "Difficultés de stationnement sur le lieu de travail ou d'études": '',
  'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
  'Fréquence marche': '',
  "Fréquence d’utilisation d'un vélo": 'Jamais',
  "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
  'Fréquence d’utilisation de la VP conducteur': 'Jamais',
  'Fréquence d’utilisation de la VP passager': 'Au moins 2 déplacements par semaine',
  'Fréquence d’utilisation du réseau urbain': 'Exceptionnellement',
  'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
  'Travail la veille': '',
  'Coefficient de redressement toutes personnes': '19.2385',
  'Coefficient de redressement personnes enquêtées': '19.2385'},
    
    
 15: {'Zone fine': '00001005',
  'Num Echantillon': '17',
  'Num Personne': '6',
  'Insee Zone Fine': '31555',
  'STP': '0001',
  'ANNEE': '2012',
  'MOIS': '11',
  'DATE': '24',
  'JOUR': 'vendredi',
  'Personne Enquêtée': 'Oui',
  'Sexe': 'Masculin',
  'Lien avec la personne de référence': 'Enfant',
  'Âge': '7',
  'Tél Portable': 'Non',
  'Mail': 'Non',
  'Permis de conduire': 'NON',
  "Niveau d'études": 'En cours de scolarité',
  'Occupation principale de la personne': "Scolaire jusqu'au bac",
  'Occupation Secondaire': 'Non concerné',
  'Professions et Catégories Socioprofessionnelles Courte': 'Élèves, étudiants',
  'Professions et Catégories Socioprofessionnelles Détaillé': 'Écoliers (primaire)',
  'Abonnement TC Valide': 'Non',
  'Travail, étude à domicile': 'Non',
  "Zone de travail ou d'études": '00001006',
  "Distance domicile-travail/étude à vol d'oiseau": '147',
  'Insee Zone fine': '31555',
  'STW': '0001',
  "VP conducteur pour se rendre sur le lieu de travail ou d'études": '',
  "Problèmes de stationnement sur le lieu de travail ou d'études": '',
  "Difficultés de stationnement sur le lieu de travail ou d'études": '',
  'STATIONNEMENT VELO SUR LE LIEU DE TRAVAIL/ETUDES': '',
  'Fréquence marche': '',
  "Fréquence d’utilisation d'un vélo": 'Jamais',
  "Fréquence d’utilisation d'un deux-roues motorisé": 'Jamais',
  'Fréquence d’utilisation de la VP conducteur': 'Jamais',
  'Fréquence d’utilisation de la VP passager': 'Au moins 2 déplacements par semaine',
  'Fréquence d’utilisation du réseau urbain': 'Exceptionnellement',
  'Situation la veille du jour d’enquête': "Oui, déplacement dans la zone d'enquête",
  'Travail la veille': '',
  'Coefficient de redressement toutes personnes': '19.2385',
  'Coefficient de redressement personnes enquêtées': '19.2385'}
